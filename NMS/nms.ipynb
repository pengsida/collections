# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('heatmap.pkl', 'rb') as f:
    prob = pickle.load(f)
print(prob.shape)
# Out:
# (256, 256)

# %%
plt.imshow(prob)
plt.show()

# %%
from nms import nms_2d
import numpy as np

# %%
inds = nms_2d(prob, wsize=40)
output = np.zeros_like(prob)
output[inds[:, 0], inds[:, 1]] = 1
plt.imshow(output)
plt.show()
